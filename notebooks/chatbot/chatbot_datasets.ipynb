# %%
# !pip install StringIO

# %%
import pandas as pd
from zipfile import ZipFile

# %%
# %cd ../../data/chatbot
# !ls
# Out:
# /usr/local/bin/notebooks/data/chatbot
# Consumer_Complaints.csv		 frames-data-v1.tar.gz	   twcs.csv
# cl2017sample.tar.gz		 frames.json		   twcs_tmobile.csv
# customer-support-on-twitter.zip  telco-customer-churn.zip

# %% [markdown]
# #### Travel

# %%
# f = 'frames.json'
# with open(f) as file:
#     json_dict = json.load(file)

# %%
# print('top-level-keys: {}'.format(list(json_dict[0].keys())))
# json_dict[0]
# json_dict[1]['turns'][2]
# len(json_dict[1]['turns'])
# json_dict[1]['turns'][19]
# json_dict[1]['turns'][0]['text']
# json_dict[1]['turns'][0]['labels']

# %% [markdown]
# #### Telco
# * https://www.kaggle.com/blastchar/telco-customer-churn#WA_Fn-UseC_-Telco-Customer-Churn.csv
# * https://www.kaggle.com/abhinav89/telecom-customer/data
# * https://www.kaggle.com/ikalats/TechnologyPriceIndex
# * https://www.kaggle.com/rtatman/santa-barbara-corpus-of-spoken-american-english
# * https://lionbridge.ai/datasets/15-best-chatbot-datasets-for-machine-learning/
# * https://www.ibm.com/communities/analytics/watson-analytics-blog/guide-to-sample-datasets/

# %%
zf = ZipFile('telco-customer-churn.zip') 
application_train = pd.read_csv(zf.open('WA_Fn-UseC_-Telco-Customer-Churn.csv'))

# %%
application_train.columns
application_train.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df = application_train.copy()
df = df[df.customerID.isin(['5575-GNVDE', '3668-QPYBK', '7469-LKBCI'])]
df[['customerID', 'Contract', 'MonthlyCharges', 'TotalCharges']]
# Out:
#     customerID        Contract  MonthlyCharges TotalCharges
# 1   5575-GNVDE        One year           56.95       1889.5
# 2   3668-QPYBK  Month-to-month           53.85       108.15
# 11  7469-LKBCI        Two year           18.95        326.8

# %%
application_train.head()
application_train[application_train.Contract=='Two year'].head()
application_train[application_train.customerID=='5575-GNVDE'].T
# row = application_train[application_train.customerID=='5575-GNVDE']
# row.Contract.values[0]
# Out:
#                              1
# customerID          5575-GNVDE
# gender                    Male
# SeniorCitizen                0
# Partner                     No
# Dependents                  No
# tenure                      34
# PhoneService               Yes
# MultipleLines               No
# InternetService            DSL
# OnlineSecurity             Yes
# OnlineBackup                No
# DeviceProtection           Yes
# TechSupport                 No
# StreamingTV                 No
# StreamingMovies             No
# Contract              One year
# PaperlessBilling            No
# PaymentMethod     Mailed check
# MonthlyCharges           56.95
# TotalCharges            1889.5
# Churn                       No

# %%
5575-GNVDE

# %% [markdown]
# #### Twitter
#
# * https://www.kaggle.com/thoughtvector/customer-support-on-twitter

# %%
df = pd.read_csv('twcs.csv')
df.head()
# Out:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0

# %%
df_tm = df[(df.author_id=='TMobileHelp') | (df.text.str.contains('@TMobileHelp'))]
df_tm.to_csv('twcs_tmobile.csv')
len(df_tm)
# Out:
# 56165

# %%
# df['created_at'] =  pd.to_datetime(df['created_at'], format='%a %b %d %H:%M:%S %z %Y')
# df.dtypes

# %%
list(df.author_id.unique())
df2 = df[df.author_id=='TMobileHelp']
df2.head()
# df2.to_csv('twcs_tmobile.csv')
# Out:
#      tweet_id    author_id  inbound                      created_at  \
# 620      1066  TMobileHelp    False  Tue Oct 31 22:28:46 +0000 2017
# 627      1156  TMobileHelp    False  Tue Oct 31 22:24:01 +0000 2017
# 630      1160  TMobileHelp    False  Tue Oct 31 22:23:40 +0000 2017
# 632      1162  TMobileHelp    False  Tue Oct 31 22:22:53 +0000 2017
# 634      1164  TMobileHelp    False  Tue Oct 31 22:20:29 +0000 2017
#
#                                                   text response_tweet_id  \
# 620  @115910 Hey, Trevor! Send us a DM, and we'll t...               NaN
# 627  @115912 @115913 Thanks for getting that DM sen...               NaN
# 630  @115914 Yay for T-Mobile Tuesdays- lets's get ...               NaN
# 632  @115915 Well, we'd be happy to take a look at ...               NaN
# 634  @115916 Hey we are here and we want to help! I...               NaN
#
#      in_response_to_tweet_id
# 620                   1067.0
# 627                   1157.0
# 630                   1161.0
# 632                   1163.0
# 634                   1165.0

# %%
len(df2)
# Out:
# 34317

# %%
df2[df2.text.str.contains('iphone')]
# Out:
#          tweet_id    author_id  inbound                      created_at  \
# 225328     261397  TMobileHelp    False  Thu Oct 05 21:47:48 +0000 2017
# 733984     820289  TMobileHelp    False  Thu Oct 12 21:43:12 +0000 2017
# 933395    1035665  TMobileHelp    False  Mon Oct 23 01:03:54 +0000 2017
# 1197218   1321164  TMobileHelp    False  Fri Oct 27 09:34:10 +0000 2017
# 1198283   1322627  TMobileHelp    False  Fri Oct 27 10:30:00 +0000 2017
#
#                                                       text  \
# 225328   @178239 did you get new iphone in December *Ge...
# 733984   @315409 If there is no liquid or physical dama...
# 933395   @364975 Which storage size was it? Is this you...
# 1197218  @428330 I see one order for an iphone x 64 gb ...
# 1198283  @428667 what device are u referring to? iphone...
#
#                response_tweet_id  in_response_to_tweet_id
# 225328             261399,261400                 261396.0
# 733984      820284,820290,820291                 820292.0
# 933395                   1035664                1035666.0
# 1197218  1321165,1321166,1321167                1321163.0
# 1198283                  1322628                1322626.0

# %%
df[df.tweet_id==1321165]
# Out:
#          tweet_id author_id  inbound                      created_at  \
# 1197219   1321165    428330     True  Fri Oct 27 09:36:43 +0000 2017
#
#                                                       text response_tweet_id  \
# 1197219  @TMobileHelp Just wanted to make sure you were...               NaN
#
#          in_response_to_tweet_id
# 1197219                1321164.0

# %%
first_contact = []
df3 = df2[~df2.response_tweet_id.isnull()]
df3.head()
# Out:
#       tweet_id    author_id  inbound                      created_at  \
# 638       1168  TMobileHelp    False  Tue Oct 31 21:49:44 +0000 2017
# 640       1171  TMobileHelp    False  Tue Oct 31 15:33:18 +0000 2017
# 642       1173  TMobileHelp    False  Tue Oct 31 14:30:29 +0000 2017
# 1351      1977  TMobileHelp    False  Tue Oct 31 22:39:50 +0000 2017
# 1353      1980  TMobileHelp    False  Tue Oct 31 23:07:51 +0000 2017
#
#                                                    text response_tweet_id  \
# 638   @115917 We want to help you with this great #T...         1167,1169
# 640   @115918 You are welcome and thanks for letting...              1170
# 642   @115918 We want this to work perfectly! Do you...              1172
# 1351  @116151 @115913 I've got your DM and will repl...              1978
# 1353  @116151 @115913 Please meet me back in DM, we'...    1982,1983,1984
#
#       in_response_to_tweet_id
# 638                    1170.0
# 640                    1172.0
# 642                    1174.0
# 1351                   1979.0
# 1353                   1978.0

# %%
for i in list(df3.response_tweet_id):
    first_contact.append(i.split(',')[0])
first_contact[:5]
# Out:
# ['1167', '1170', '1172', '1978', '1982']

# %%
df[df.tweet_id.isin(first_contact)].head()
# Out:
#       tweet_id author_id  inbound                      created_at  \
# 637       1167    115917     True  Tue Oct 31 22:13:16 +0000 2017
# 639       1170    115917     True  Tue Oct 31 21:47:53 +0000 2017
# 641       1172    115918     True  Tue Oct 31 15:20:26 +0000 2017
# 1352      1978    116151     True  Tue Oct 31 23:04:28 +0000 2017
# 1354      1982    116151     True  Tue Oct 31 23:16:48 +0000 2017
#
#                                                    text response_tweet_id  \
# 637               @TMobileHelp  https://t.co/tznFggbx3Y              1166
# 639   @TMobileHelp @115918 OK maybe my problem too l...              1168
# 641   @TMobileHelp Got it. One of them resized to 4x...              1171
# 1352  @TMobileHelp @115913 John why I am having so m...         1980,1981
# 1354  @TMobileHelp @115913 8 hours total  over 3 day...              1985
#
#       in_response_to_tweet_id
# 637                    1168.0
# 639                    1171.0
# 641                    1173.0
# 1352                   1977.0
# 1354                   1980.0

# %%
to_tmobile = df[df.text.str.contains('@TMobileHelp')].sort_values(by='author_id')

# %%
to_tmobile.head()
# Out:
#          tweet_id author_id  inbound                      created_at  \
# 2456734   2626085     10766     True  Mon Oct 30 23:50:21 +0000 2017
# 2456736   2325795     10766     True  Mon Oct 30 20:43:33 +0000 2017
# 1549000   1699348    115725     True  Mon Nov 06 23:50:43 +0000 2017
# 2343154   2509795    115809     True  Wed Nov 15 22:38:04 +0000 2017
# 1950265   2105295    115892     True  Wed Nov 08 12:59:46 +0000 2017
#
#                                                       text response_tweet_id  \
# 2456734  @47293 @115911 @TMobileHelp @2816 @136221 work...           2626084
# 2456736  @47293 @115911 @TMobileHelp @2816 Looks like i...           2626086
# 1549000                    @515339 @TMobileHelp @115913 👋🏻           1699350
# 2343154  @TMobileHelp @115913 Not covered.  No Jump or ...           2509794
# 1950265  @TMobileHelp hi! I understand there were some ...           2105294
#
#          in_response_to_tweet_id
# 2456734                2626086.0
# 2456736                2325794.0
# 1549000                1699346.0
# 2343154                2509796.0
# 1950265                      NaN
